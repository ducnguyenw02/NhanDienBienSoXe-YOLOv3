# %%
# !nvidia-smi
# Out:
# Mon Jun 13 07:35:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# 'Colab Notebooks'  'Đồ án ML'   yolov3

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15424, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 15424 (delta 0), reused 0 (delta 0), pack-reused 15423
# Receiving objects: 100% (15424/15424), 14.05 MiB | 8.65 MiB/s, done.
# Resolving deltas: 100% (10364/10364), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %%
# Create folder on google drive so that we can save there the weights
# !mkdir "/mydrive/yolov3"
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov3’: File exists

# %%
# !echo "bien so xe" > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-06-13 07:38:04--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  18.4MB/s    in 9.6s
#
# 2022-06-13 07:38:15 (16.2 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !unzip /mydrive/yolov3/images.zip -d data/obj

# %%
# We're going to convert the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
import glob
import os
import re

txt_file_paths = glob.glob(r"data/obj/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
print(images_list)
# Out:
# ['data/obj/plate  (711).jpg', 'data/obj/plate  (365).jpg', 'data/obj/plate  (482).jpg', 'data/obj/plate  (175).jpg', 'data/obj/plate  (504).jpg', 'data/obj/plate  (489).jpg', 'data/obj/plate  (323).jpg', 'data/obj/plate  (420).jpg', 'data/obj/plate  (355).jpg', 'data/obj/plate  (142).jpg', 'data/obj/plate  (461).jpg', 'data/obj/plate  (765).jpg', 'data/obj/plate  (363).jpg', 'data/obj/plate  (333).jpg', 'data/obj/plate  (521).jpg', 'data/obj/plate  (235).jpg', 'data/obj/plate  (406).jpg', 'data/obj/plate  (31).jpg', 'data/obj/plate  (708).jpg', 'data/obj/plate  (291).jpg', 'data/obj/plate  (70).jpg', 'data/obj/plate  (839).jpg', 'data/obj/plate  (509).jpg', 'data/obj/plate  (457).jpg', 'data/obj/plate  (678).jpg', 'data/obj/plate  (403).jpg', 'data/obj/plate  (320).jpg', 'data/obj/plate  (238).jpg', 'data/obj/plate  (150).jpg', 'data/obj/plate  (37).jpg', 'data/obj/plate  (305).jpg', 'data/obj/plate  (147).jpg', 'data/obj/plate  (68).jpg', 'data/obj/plate  (850).jpg', 'data/obj/plate  (508).jpg', 'data/obj/plate  (144).jpg', 'data/obj/plate  (342).jpg', 'data/obj/plate  (405).jpg', 'data/obj/plate  (713).jpg', 'data/obj/plate  (802).jpg', 'data/obj/plate  (480).jpg', 'data/obj/plate  (534).jpg', 'data/obj/plate  (328).jpg', 'data/obj/plate  (157).jpg', 'data/obj/plate  (126).jpg', 'data/obj/plate  (388).jpg', 'data/obj/plate  (893).jpg', 'data/obj/plate  (815).jpg', 'data/obj/plate  (847).jpg', 'data/obj/plate  (232).jpg', 'data/obj/plate  (83).jpg', 'data/obj/plate  (451).jpg', 'data/obj/plate  (336).jpg', 'data/obj/plate  (173).jpg', 'data/obj/plate  (180).jpg', 'data/obj/plate  (488).jpg', 'data/obj/plate  (896).jpg', 'data/obj/plate  (849).jpg', 'data/obj/plate  (190).jpg', 'data/obj/plate  (271).jpg', 'data/obj/plate  (445).jpg', 'data/obj/plate  (326).jpg', 'data/obj/plate  (292).jpg', 'data/obj/plate  (61).jpg', 'data/obj/plate  (11).jpg', 'data/obj/plate  (566).jpg', 'data/obj/plate  (440).jpg', 'data/obj/plate  (101).jpg', 'data/obj/plate  (88).jpg', 'data/obj/plate  (71).jpg', 'data/obj/plate  (201).jpg', 'data/obj/plate  (316).jpg', 'data/obj/plate  (410).jpg', 'data/obj/plate  (886).jpg', 'data/obj/plate  (479).jpg', 'data/obj/plate  (833).jpg', 'data/obj/plate  (400).jpg', 'data/obj/plate  (776).jpg', 'data/obj/plate  (265).jpg', 'data/obj/plate  (885).jpg', 'data/obj/plate  (732).jpg', 'data/obj/plate  (367).jpg', 'data/obj/plate  (686).jpg', 'data/obj/plate  (94).jpg', 'data/obj/plate  (41).jpg', 'data/obj/plate  (806).jpg', 'data/obj/plate  (6).jpg', 'data/obj/plate  (570).jpg', 'data/obj/plate  (59).jpg', 'data/obj/plate  (741).jpg', 'data/obj/plate  (46).jpg', 'data/obj/plate  (808).jpg', 'data/obj/plate  (491).jpg', 'data/obj/plate  (48).jpg', 'data/obj/plate  (393).jpg', 'data/obj/plate  (516).jpg', 'data/obj/plate  (514).jpg', 'data/obj/plate  (782).jpg', 'data/obj/plate  (486).jpg', 'data/obj/plate  (258).jpg', 'data/obj/plate  (2).jpg', 'data/obj/plate  (29).jpg', 'data/obj/plate  (196).jpg', 'data/obj/plate  (683).jpg', 'data/obj/exception (21).jpg', 'data/obj/plate  (785).jpg', 'data/obj/plate  (724).jpg', 'data/obj/plate  (39).jpg', 'data/obj/plate  (384).jpg', 'data/obj/plate  (561).jpg', 'data/obj/plate  (215).jpg', 'data/obj/plate  (715).jpg', 'data/obj/plate  (517).jpg', 'data/obj/plate  (137).jpg', 'data/obj/plate  (102).jpg', 'data/obj/plate  (294).jpg', 'data/obj/plate  (143).jpg', 'data/obj/plate  (105).jpg', 'data/obj/plate  (116).jpg', 'data/obj/plate  (475).jpg', 'data/obj/plate  (441).jpg', 'data/obj/plate  (380).jpg', 'data/obj/plate  (772).jpg', 'data/obj/plate  (841).jpg', 'data/obj/exception (14).jpg', 'data/obj/plate  (236).jpg', 'data/obj/plate  (176).jpg', 'data/obj/plate  (677).jpg', 'data/obj/plate  (285).jpg', 'data/obj/exception (10).jpg', 'data/obj/plate  (269).jpg', 'data/obj/plate  (125).jpg', 'data/obj/plate  (549).jpg', 'data/obj/plate  (8).jpg', 'data/obj/plate  (244).jpg', 'data/obj/plate  (154).jpg', 'data/obj/plate  (332).jpg', 'data/obj/plate  (182).jpg', 'data/obj/pla ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
